# %%
import matplotlib.pyplot as plt

# %%
x =[1,2,3,4,5,6,7,8]
y =[40,45,50,55,60,65,70,75]

# %%
plt.figure(figsize=(8,6))
plt.scatter(x,y,color='pink',marker='D')
plt.xlabel("Hours studied")
plt.ylabel("Test score")
plt.title("Scatter plot of Hours studied vs Test score ")
plt.grid()

# %%
x =[1,2,3,4,5,6,7,8]
y =[50,55,60,65,70,75,80,85]

# %%
size =[100,200,300,400,500,600,700,800]

# %%
plt.scatter(x,y,s=size,alpha=0.5,color='red',edgecolors='k')

# plt.grid()
